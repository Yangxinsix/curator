# %%
from curator.utils import read_user_config
from hydra.utils import instantiate
# Out:
# /home/xinyang/miniconda3/lib/python3.13/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# Failed to get GPU information from pynvml: Not Supported. Using default values.
# GPU information: NVIDIA RTX A6000, 8, 6, 45, 84, 300, 2100

# %%
from ase import units

# %%
units.fs * 0.5
# Out:
# 0.04911347394232032

# %%
cfg = read_user_config("plumed.yaml", config_name="simulate.yaml")

# %%
cfg
# Out:
# {'simulator': {'engine': {'_target_': 'curator.simulate.engines.ase_md.MDEngine', 'dynamics_cls': 'ase.md.langevin.Langevin', 'timestep': 0.5, 'friction': 0.2, 'temperature_K': 300}, '_target_': 'curator.simulate.core.simulator.Simulator', 'init_traj': '/home/xinyang/curator/test/LiFePO4.traj', 'start_index': None, 'run_kwargs': {'steps': 1000}, 'callbacks': [{'_target_': 'curator.simulate.callbacks.calc.CalculatorAssign', '_partial_': True, 'calculator': {'_target_': 'ase.calculators.plumed.Plumed', '_partial_': True, 'calc': {'_target_': 'curator.simulate.core.calculator.MLCalculator', 'model': '/home/xinyang/curator/test/best_model.ckpt', 'device': 'cpu'}, 'input': None, 'timestep': 0.5, 'kT': 300}, 'warmup': True, 'require_forces': False, 'apply_to_neb_images': False, 'device': 'cpu'}, {'_target_': 'curator.simulate.callbacks.thermo_uncertainty.ThermoWithUncertainty', 'variables': 'basic_energies', 'interval': 1, 'header': True, 'monitor': 'maha_dist', 'low': None, 'high': None, 
# ...

# %%
calc = instantiate(cfg.simulator.callbacks[0])
# Out:
# /home/xinyang/curator/curator/utils.py:279: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   obj = torch.load(model_file, map_location=torch.device(device))

# %%
calc._make_calc()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 calc._make_calc()
#
# File ~/curator/curator/simulate/callbacks/calc.py:59, in CalculatorAssign._make_calc(self)
#      57 # Factory returning a calculator
#      58 if callable(self._calculator) and not isinstance(self._calculator, (str, bytes)):
# ---> 59     return self._calculator()
#      61 # Model-like: path(s) or module(s)
#      62 model_like: Any = self._calculator
#
# File ~/miniconda3/lib/python3.13/site-packages/ase/calculators/plumed.py:112, in Plumed.__init__(self, calc, input, timestep, atoms, kT, log, restart, use_charge, update_charge)
#      52 def __init__(self, calc, input, timestep, atoms=None, kT=1., log='',
#      53              restart=False, use_charge=False, update_charge=False):
#      54     """
# ...

# %%
calc
# Out:
# functools.partial(<class 'ase.calculators.plumed.Plumed'>, calc=<curator.simulate.core.calculator.MLCalculator object at 0x7dab08f40050>, input=None, timestep=0.5, kT=300)

# %%
calc.model
# Out:
# NeuralNetworkPotential(
#   (representation): Painn(
#     (atom_embedding): Embedding(119, 128)
#     (message_layers): ModuleList(
#       (0-2): 3 x PainnMessage(
#         (cutoff_fn): CosineCutoff()
#         (radial_basis): SineBasis()
#         (scalar_message_mlp): Sequential(
#           (0): Linear(in_features=128, out_features=128, bias=True)
#           (1): SiLU()
#           (2): Linear(in_features=128, out_features=384, bias=True)
#         )
#         (filter_layer): Linear(in_features=20, out_features=384, bias=True)
#       )
#     )
#     (update_layers): ModuleList(
#       (0-2): 3 x PainnUpdate(
#         (update_U): Linear(in_features=128, out_features=128, bias=True)
#         (update_V): Linear(in_features=128, out_features=128, bias=True)
#         (update_mlp): Sequential(
#           (0): Linear(in_features=256, out_features=128, bias=True)
#           (1): SiLU()
#           (2): Linear(in_features=128, out_features=384, bias=True)
#         )
#       )
# ...
